# %% [markdown]
# ## My input:
#
# Create two persona sample for desing thinking workshop. Sandy is a mother who works 8hours per week and Cris who is a soccer player. In the workshop we are goingo to design a mobile app for purchase insurances.

# %% [markdown]
# ## Granite 13B v2.1 / VS Code Assistant output
#
# Create two persona sample for ...
# Response Time (in Secs): 15.10s
#
# Prompt: Create two persona sample for desing thinking workshop. Sandy is a mother who works 8hours per week ...
# Model: Granite 13B V2.1
# Message Tokens: 76, Answer Tokens: 239, Total Tokens: 315
# Response Time (in Secs): 15.10s
# **Sandy - Mother, Part-time Worker**
#
# Sandy is a 35-year-old mother of two young children. She works part-time as a sales associate at a local store, putting in around 8 hours per week. Sandy values her time and looks for ways to make it more efficient. She often juggles multiple tasks, including work, family responsibilities, and household chores. She finds herself wishing for a tool that can help her manage her time better, stay organized, and keep track of her finances.
#
# **Cris - Soccer Player**
#
# Cris is a 28-year-old professional soccer player. He lives an active lifestyle and is always on the go. Cris needs a way to organize his busy schedule, manage his finances, and communicate with his teammates effectively. He is looking for a mobile app that can help him stay organized, track his expenses, and connect with his teammates.
#
# As a Design Thinking Workshop facilitator, it would be valuable to understand these personas to create a user-centered design that addresses their needs and pain points. The workshop can involve activities such as user research, prototyping, and usability testing to ensure that the mobile app is tailored to their specific requirements.
#
# ![Granite 13B v2.1 / VS Code Assistant output](1_Granite_13B_v2.1_VS_Code_Assistant_output.png)

# %% [markdown]
# ## Llama3 8B Instruct/ VS Code Assistant output
#
# Create two persona sample for ...
# Response Time (in Secs): 10.62s
#
# Prompt: Create two persona sample for desing thinking workshop. Sandy is a mother who works 8hours per week ...
# Model: Llama3 8B Instruct
# Message Tokens: 76, Answer Tokens: 336, Total Tokens: 412
# Response Time (in Secs): 10.62s
# Here are two persona samples for the design thinking workshop:
#
# **Persona 1: Sandy**
#
# Name: Sandy
#
# Age: 35
#
# Occupation: Part-time working mother (8 hours/week)
#
# Goal: To ensure her family's financial security and protect their assets
#
# Values:
#
# * Family first
# * Financial stability
# * Convenience
# * Ease of use
#
# Pain Points:
#
# * Difficulty understanding insurance options and jargon
# * Limited time to research and compare policies
# * Frustration with manual processes and paperwork
# * Concerns about the security of her family's financial information
#
# Behavioral Patterns:
#
# * Researches and compares insurance options online
# * Values convenience and ease of use
# * Prioritizes financial security for her family
# * May seek advice from friends, family, or a financial advisor
#
# **Persona 2: Cris**
#
# Name: Cris
#
# Age: 28
#
# Occupation: Professional soccer player
#
# Goal: To protect his career and financial future
#
# Values:
#
# * Risk management
# * Financial security
# * Convenience
# * Flexibility
#
# Pain Points:
#
# * Concerns about the financial impact of an unexpected injury or illness
# * Difficulty understanding insurance options and jargon
# * Limited time to research and compare policies
# * Frustration with manual processes and paperwork
#
# Behavioral Patterns:
#
# * Researches and compares insurance options online
# * Values convenience and ease of use
# * Prioritizes financial security for his career and future
# * May seek advice from a financial advisor or agent
#
# These personas can help guide the design thinking workshop and ensure that the mobile app for purchasing insurance is designed with the needs and pain points of real users in mind.
#
# ![Llama3 8B Instruct/ VS Code Assistant output](Llama3_8B_Instruct_VS_Code_Assistant_output.png)
